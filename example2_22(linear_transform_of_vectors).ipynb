# %% [markdown]
# <a href="https://colab.research.google.com/github/gg5d/DS-3005/blob/main/example2_22(linear_transform_of_vectors).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Example 2.2 page 52
#
# Transformations generated by a 2 by 2 matrix $A$ on $\mathbb{R}^2$ Vector Space.

# %%
import IPython.display as display

# %%
## rotation

fig01 = """
<iframe width="1000" height="600" src="https://www.geogebra.org/m/fvwpk8qh" style="border: 1px solid black"></iframe>
"""
display.HTML(fig01)
# Out:
# <iframe width="1000" height="600" src="https://www.geogebra.org/m/fvwpk8qh" style="border: 1px solid black"></iframe>

# %%
## stretch

fig02 = """
<iframe width="1000" height="600" src="https://www.geogebra.org/m/btgjejyw" style="border: 1px solid black"></iframe>
"""
display.HTML(fig02)
# Out:
# <iframe width="1000" height="600" src="https://www.geogebra.org/m/btgjejyw" style="border: 1px solid black"></iframe>

# %%
## general linear mapping

fig03 = """
<iframe width="1000" height="600" src="https://www.geogebra.org/m/zttvuxp8" style="border: 1px solid black"></iframe>
"""
display.HTML(fig03)
# Out:
# <iframe width="1000" height="600" src="https://www.geogebra.org/m/zttvuxp8" style="border: 1px solid black"></iframe>
